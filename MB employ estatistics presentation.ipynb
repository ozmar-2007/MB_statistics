# %% [markdown]
# <img src ="logoMB.png">

# %% [markdown]
# ## A base de dados: ##

# %%
df = pd.read_excel("funcionarios_MB.xls")
# Out:
#    id  Est_Civil   Gr_Instruc  Num_Filhos  Sal_min  Idade_Anos  Idade_Meses  \
# 0   1   Solteiro  fundamental           0     4.00          26            3
# 1   2     Casado  fundamental           1     4.56          32           10
# 2   3     Casado  fundamental           2     5.25          36            5
#
#   Reg_Proced
# 0   Interior
# 1    Capital
# 2    Capital

# %% [markdown]
# ### Retirando colunas inexpressivas(os meses foram adicinados como decimos aos anos inteiros)

# %%
df["Idade_Anos"]= round((df["Idade_Anos"]+(df["Idade_Meses"]/12)),2)
df.drop(['id'], axis=1, inplace=True)
df.drop(['Idade_Meses'], axis=1, inplace=True)

# %% [markdown]
# ## A tabela na íntegra:

# %%
print(df)
# Out:
#     Est_Civil   Gr_Instruc  Num_Filhos  Sal_min  Idade_Anos Reg_Proced
# 0    Solteiro  fundamental           0     4.00       26.25   Interior
# 1      Casado  fundamental           1     4.56       32.83    Capital
# 2      Casado  fundamental           2     5.25       36.42    Capital
# 3    Solteiro        medio           0     5.73       20.83      Outra
# 4    Solteiro  fundamental           0     6.26       40.58      Outra
# 5      Casado  fundamental           0     6.66       28.00   Interior
# 6    Solteiro  fundamental           0     6.86       41.00   Interior
# 7    Solteiro  fundamental           0     7.39       43.33    Capital
# 8      Casado        medio           1     7.44       34.83    Capital
# 9    Solteiro        medio           0     7.59       23.50      Outra
# 10     Casado        medio           2     8.12       33.50   Interior
# 11   Solteiro  fundamental           0     8.46       27.92    Capital
# ...

# %% [markdown]
# <p>

# %% [markdown]
# ## Síntese estatistica dos dados

# %%
df.describe()
# Out:
#        Num_Filhos    Sal_min  Idade_Anos
# count   36.000000  36.000000   36.000000
# mean     0.916667  11.117222   35.050833
# std      1.250714   4.588219    6.705046
# min      0.000000   4.000000   20.830000
# 25%      0.000000   7.552500   30.667500
# 50%      0.000000  10.075000   34.915000
# 75%      2.000000  14.060000   40.520000
# max      5.000000  23.300000   48.920000

# %% [markdown]
# <p>

# %% [markdown]
# <p>

# %% [markdown]
# <p>

# %% [markdown]
# <p>

# %% [markdown]
# <p>

# %% [markdown]
# <p>

# %% [markdown]
# <p>

# %% [markdown]
# <p>

# %% [markdown]
# <p>

# %% [markdown]
# <p>

# %% [markdown]
# ## Tentando encontrar correlações logo "de cara"...

# %%
df.corr() #retorna a correlação entre as colunas com entradas numéricas
# Out:
#             Num_Filhos   Sal_min  Idade_Anos
# Num_Filhos    1.000000  0.375564    0.426701
# Sal_min       0.375564  1.000000    0.365115
# Idade_Anos    0.426701  0.365115    1.000000

# %% [markdown]
# ### Humm... Sem muito sucesso, índices bem baixos : - (

# %% [markdown]
# ### Precisaremos de uma exploração mais a fundo. Porém,
# ### ao invés de começar por cálculos e fórmulas,  vamos
# ### deixar um overview mais visual nos mostrar algum caminho.

# %%
sns.pairplot(df, hue="Reg_Proced") # retorna um scatter para cada par de colunas,
#                                    e um histograma para o cruzamento de uma mesma
#                                    atribuindo cores para uma terceira feature:

# %% [markdown]
# ### Ficou bonitinho, mas não elucidou muita coisa.

# %% [markdown]
# <p>

# %% [markdown]
# <p>

# %% [markdown]
# ## Vamos trocar a feature a ser colorizada e ver o resultado...

# %%
sns.pairplot(df, hue="Gr_Instruc")

# %% [markdown]
# ## Hah, agora sim!
# ### Observe onde se encontram "idade" e "salario", como ficam
# ### isoladas as classes de diferentes níveis escolares.

# %% [markdown]
# <p>
# <p>
# <p>
# <p>

# %% [markdown]
# ## Vamos então usar estas caracteristicas para gerar nossos insights,
# ## gerando um novo gráfico, mais detalhado.
# #####     Temos "idade x salario" e "salário x idade".  Por convenção,
# #####     usaremos idade(tempo) no eixo das Abscissas.

# %% [markdown]
# <P>
# <P>
# <P>
# <P>
# <P>

# %% [markdown]
# <p>

# %% [markdown]
# <p>

# %% [markdown]
# <p>

# %% [markdown]
# <p>

# %% [markdown]
# <p>

# %% [markdown]
# <p>

# %% [markdown]
# <p>

# %% [markdown]
# ## Adicionalmente,foi gerado um gráfico com as retas de regressao referente a cada classe de formação escolar.

# %% [markdown]
# <p>

# %% [markdown]
# <p>

# %% [markdown]
# <p>

# %% [markdown]
# <p>

# %% [markdown]
# <p>

# %% [markdown]
# <p>

# %% [markdown]
# <p>

# %% [markdown]
# <p>

# %% [markdown]
# <p>

# %% [markdown]
# Bibliografia:
# https://programandociencia.com/
# <img src ="Programando Ciência.png">

# %% [markdown]
# ## Código fonte em meu GitHub: github.com/ozmar-2007
